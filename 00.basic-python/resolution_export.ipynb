# %%
import matplotlib.pyplot as plt
import numpy as np

from IPython import display
display.set_matplotlib_formats("svg")
# Out:
# /var/folders/bl/szm2l2gn39z8s25dy8_lztmr0000gn/T/ipykernel_1789/4117479542.py:5: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats("svg")

# %%
x  = np.linspace(.5, 5, 10)
y1 = np.log(x)
y2 = 2-np.sqrt(x)
plt.plot(x, y1, "bo-", label="log")
plt.plot(x, y2, "rs-", label="square root")
plt.legend()
# plt.savefig一定要在plt.show之前执行。
plt.savefig('test.svg')
plt.show()
